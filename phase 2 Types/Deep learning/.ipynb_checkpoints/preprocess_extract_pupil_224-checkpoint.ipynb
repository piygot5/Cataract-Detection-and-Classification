# %%
import os
subdirs = [x[0] for x in os.walk('Dataset')]
print(subdirs)
# Out:
# ['Dataset', 'Dataset\\mild', 'Dataset\\normal', 'Dataset\\normal_png', 'Dataset\\severe']

# %%
from os import listdir
from os.path import isfile, join
file_names=[]
for sub_dir in subdirs:
    if sub_dir == 'Dataset\\normal_png':
        continue
    mypath = sub_dir
    sub_folder_file_names = [mypath+"/"+f for f in listdir(mypath) if isfile(join(mypath, f))]
    file_names += sub_folder_file_names
    
print(str(len(file_names)) + ' images loaded')
# Out:
# 550 images loaded

# %%
import imutils
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
file_names[500]
# Out:
# 'Dataset\\severe/severe_54.png'

# %%
c=0
crop_radius_list = [] 
mild_path="preprocessed images_224\mild/"
severe_path="preprocessed images_224\severe/"
normal_path="preprocessed images_224/normal/"
for filename in file_names:
    #print(filename)
    img=cv2.imread(filename)
    img = cv2.resize(img, (224,224), interpolation = cv2.INTER_AREA)
    frame = img
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    sensitivity = 156
    lower_white = np.array([0,0,255-sensitivity])
    upper_white = np.array([255,sensitivity,255])
    # Threshold the HSV image to get only white colors
    mask = cv2.inRange(hsv, lower_white, upper_white)
    # Bitwise-AND mask and original image
    res = cv2.bitwise_and(frame,frame, mask= mask)
    ret, thresh = cv2.threshold(mask, 0, 255, cv2.THRESH_BINARY_INV)
    circles = cv2.HoughCircles(mask, cv2.HOUGH_GRADIENT, 1.5, 100000,param1=80,param2=40,minRadius=0,maxRadius=0)
    x,y,r = 0,0,0
    if circles is not None:
        c+=1
        circles = np.uint16(np.around(circles))
        x,y,r = circles[0][0]
        x=int(x)
        y=int(y)
        r=int(r)
        crop_radius_list.append(r)

    mask = np.zeros((224,224), np.uint8)
    cv2.circle(mask,(x,y),r,(255,255,255),-1)
    masked_data = cv2.bitwise_and(frame, frame, mask=mask)
    _,thresh = cv2.threshold(mask,1,255,cv2.THRESH_BINARY)
    cnt = cv2.findContours(thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)[0]
    x,y,w,h = cv2.boundingRect(cnt[0])

    # Crop masked_data
    crop = masked_data[y:y+h,x:x+w]
    crop = cv2.resize(crop, (224,224), interpolation = cv2.INTER_AREA)

    if filename[8] == 'm':        
        print(cv2.imwrite( mild_path+filename[13:] , crop ))
    elif filename[8] == 's':     
        print(cv2.imwrite( severe_path+filename[15:] , crop ))
    else:
        print(cv2.imwrite( normal_path+filename[15:] , crop )) 
print("Finish")
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...
